# %%
import sys
import subprocess

#import pkg_resources
#required = {'harmonypy','sklearn','scanpy','pandas', 'numpy', 'bbknn', 'scipy', 'matplotlib', 'seaborn' ,'scipy'}
#installed = {pkg.key for pkg in pkg_resources.working_set}
#missing = required - installed
#if missing:
#    print("Installing missing packages:" )
#    print(missing)
#    python = sys.executable
#    subprocess.check_call([python, '-m', 'pip', 'install', *missing], stdout=subprocess.DEVNULL)

# %matplotlib inline
from collections import Counter
from collections import defaultdict
import scanpy as sc
import pandas as pd
import pickle as pkl
import numpy as np
from bbknn import bbknn
import scipy
import matplotlib.pyplot as plt
import re
import glob
import os
import sys
from geosketch import gs
from numpy import cov
import scipy.cluster.hierarchy as spc
import seaborn as sns; sns.set(color_codes=True)
from sklearn.linear_model import LogisticRegression
import sklearn
import harmonypy as hm
from pathlib import Path
import ppscore as pps
import pathlib
import os

sc.settings.verbosity = 3  # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.settings.set_figure_params(dpi=300, color_map='viridis')
plt.rcParams['figure.figsize'] = [15, 15]

# %%
run_name = 'Early_late_DEGS'
Object = '/nfs/team205/ig7/work_backups/backup_210306/projects/YS/YS_data/A4_V7_YS_integrated_data_singlets_normalised_counts_for_MS_plotting_20211111_with_obsp.h5ad'
save_path = "/nfs/team205/ig7/work_backups/backup_210306/projects/YS/YS_310122_notebooks/fig1_background/scMILO/genescore_metabolic_early_late/"
pd_paths = "/nfs/team205/ig7/work_backups/backup_210306/projects/YS/YS_310122_notebooks/fig1_background/scMILO/sig_FC_early_late_neighbourhoods"
save_loc = './outs/'

# Required: Name of first object
data1 = "_ys"
# Provide categorical to join between datasets
cat1 = "cell.labels"

# %%
import os
if not os.path.exists(save_loc):
    os.makedirs(save_loc)
adata = sc.read(Object)
adata.obs.columns
# Out:
# Index(['cell.labels', 'stage', 'lanes', 'sex', 'sort.ids', 'fetal.ids',
#        'component', 'broad_cell.labels', 'sequencing.type', 'orig.dataset',
#        'broad_cell_labels_organ', 'tissue', 'V6_old_indexes', 'n_counts'],
#       dtype='object')

# %% [markdown]
# # Update adata metadata

# %%
obs = pd.read_csv('/nfs/team205/ig7/work_backups/backup_210306/projects/YS/resources/A2_V7_YS_main_metadata_161121.csv',index_col=0)
adata.obs = obs
adata.obs.index = adata.obs.index.str.replace('_1','')

# %%
adata.obs
# Out:
#                                                       cell.labels stage  \
# Wang_et_al_AAACCTGAGACCTTTG                         Sinusoidal_EC  CS10
# Wang_et_al_AAACCTGCACCTATCC                                  MEMP  CS10
# Wang_et_al_AAACCTGCACTTAAGC                                HSPC_1  CS10
# Wang_et_al_AAACCTGGTAACGACG                             Erythroid  CS10
# Wang_et_al_AAACCTGGTCAAAGAT                             Erythroid  CS10
# ...                                                           ...   ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...      Erythroid  CS15
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...    Immature_EC  CS15
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...    Immature_EC  CS15
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...      Erythroid  CS15
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...    Mesothelium  CS15
#
#                                                              lanes   sex  \
# Wang_et_al_AAACCTGAGACCTTTG                              Wang_CS10  Male
# Wang_et_al_AAACCTGCACCTATCC                              Wang_CS10  Male
# Wang_et_al_AAACCTGCACTTAAGC                              Wang_CS10  Male
# Wang_et_al_AAACCTGGTAACGACG                              Wang_CS10  Male
# Wang_et_al_AAACCTGGTCAAAGAT                              Wang_CS10  Male
# ...                                                            ...   ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...  FCAImmP8096696  Male
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...  FCAImmP8096696  Male
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...  FCAImmP8096696  Male
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...  FCAImmP8096696  Male
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...  FCAImmP8096696  Male
#
#                                                    sort.ids  fetal.ids  \
# Wang_et_al_AAACCTGAGACCTTTG                           Total  Wang_CS10
# Wang_et_al_AAACCTGCACCTATCC                           Total  Wang_CS10
# Wang_et_al_AAACCTGCACTTAAGC                           Total  Wang_CS10
# Wang_et_al_AAACCTGGTAACGACG                           Total  Wang_CS10
# Wang_et_al_AAACCTGGTCAAAGAT                           Total  Wang_CS10
# ...                                                     ...        ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...  CD45NAF        F80
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...  CD45NAF        F80
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...  CD45NAF        F80
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...  CD45NAF        F80
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...  CD45NAF        F80
#
#                                                    component  \
# Wang_et_al_AAACCTGAGACCTTTG                         Membrane
# Wang_et_al_AAACCTGCACCTATCC                         Membrane
# Wang_et_al_AAACCTGCACTTAAGC                         Membrane
# Wang_et_al_AAACCTGGTAACGACG                         Membrane
# Wang_et_al_AAACCTGGTCAAAGAT                         Membrane
# ...                                                      ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...  Membrane
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...  Membrane
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...  Membrane
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...  Membrane
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...  Membrane
#
#                                                    broad_cell.labels  \
# Wang_et_al_AAACCTGAGACCTTTG                              Endothelium
# Wang_et_al_AAACCTGCACCTATCC                              Progenitors
# Wang_et_al_AAACCTGCACTTAAGC                              Progenitors
# Wang_et_al_AAACCTGGTAACGACG                                Erythroid
# Wang_et_al_AAACCTGGTCAAAGAT                                Erythroid
# ...                                                              ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...         Erythroid
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...       Endothelium
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...       Endothelium
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...         Erythroid
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...       Mesothelium
#
#                                                    sequencing.type  \
# Wang_et_al_AAACCTGAGACCTTTG                                    TBC
# Wang_et_al_AAACCTGCACCTATCC                                    TBC
# Wang_et_al_AAACCTGCACTTAAGC                                    TBC
# Wang_et_al_AAACCTGGTAACGACG                                    TBC
# Wang_et_al_AAACCTGGTCAAAGAT                                    TBC
# ...                                                            ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...            5GEX
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...            5GEX
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...            5GEX
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...            5GEX
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...            5GEX
#
#                                                                       orig.dataset  \
# Wang_et_al_AAACCTGAGACCTTTG                         Wang_et_al_Cell_Stem Cell_2021
# Wang_et_al_AAACCTGCACCTATCC                         Wang_et_al_Cell_Stem Cell_2021
# Wang_et_al_AAACCTGCACTTAAGC                         Wang_et_al_Cell_Stem Cell_2021
# Wang_et_al_AAACCTGGTAACGACG                         Wang_et_al_Cell_Stem Cell_2021
# Wang_et_al_AAACCTGGTCAAAGAT                         Wang_et_al_Cell_Stem Cell_2021
# ...                                                                            ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...                         De_novo
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...                         De_novo
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...                         De_novo
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...                         De_novo
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...                         De_novo
#
#                                                    broad_cell_labels_organ  \
# Wang_et_al_AAACCTGAGACCTTTG                                 Endothelium_ys
# Wang_et_al_AAACCTGCACCTATCC                                 Progenitors_ys
# Wang_et_al_AAACCTGCACTTAAGC                                 Progenitors_ys
# Wang_et_al_AAACCTGGTAACGACG                                   Erythroid_ys
# Wang_et_al_AAACCTGGTCAAAGAT                                   Erythroid_ys
# ...                                                                    ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...            Erythroid_ys
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...          Endothelium_ys
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...          Endothelium_ys
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...            Erythroid_ys
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...          Mesothelium_ys
#
#                                                    tissue  \
# Wang_et_al_AAACCTGAGACCTTTG                            YS
# Wang_et_al_AAACCTGCACCTATCC                            YS
# Wang_et_al_AAACCTGCACTTAAGC                            YS
# Wang_et_al_AAACCTGGTAACGACG                            YS
# Wang_et_al_AAACCTGGTCAAAGAT                            YS
# ...                                                   ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...     YS
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...     YS
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...     YS
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...     YS
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...     YS
#
#                                                                                        V6_old_indexes  \
# Wang_et_al_AAACCTGAGACCTTTG                                             Wang_et_al_AAACCTGAGACCTTTG_1
# Wang_et_al_AAACCTGCACCTATCC                                             Wang_et_al_AAACCTGCACCTATCC_1
# Wang_et_al_AAACCTGCACTTAAGC                                             Wang_et_al_AAACCTGCACTTAAGC_1
# Wang_et_al_AAACCTGGTAACGACG                                             Wang_et_al_AAACCTGGTAACGACG_1
# Wang_et_al_AAACCTGGTCAAAGAT                                             Wang_et_al_AAACCTGGTCAAAGAT_1
# ...                                                                                               ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...  F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATC...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...  F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGAT...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...  F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCG...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...  F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCAT...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...  F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGG...
#
#                                                                                        V5_old_indexes
# Wang_et_al_AAACCTGAGACCTTTG                         Cell_dat_Yolksac_Cell_dat_Yolksac_AAACCTGAGACC...
# Wang_et_al_AAACCTGCACCTATCC                         Cell_dat_Yolksac_Cell_dat_Yolksac_AAACCTGCACCT...
# Wang_et_al_AAACCTGCACTTAAGC                         Cell_dat_Yolksac_Cell_dat_Yolksac_AAACCTGCACTT...
# Wang_et_al_AAACCTGGTAACGACG                         Cell_dat_Yolksac_Cell_dat_Yolksac_AAACCTGGTAAC...
# Wang_et_al_AAACCTGGTCAAAGAT                         Cell_dat_Yolksac_Cell_dat_Yolksac_AAACCTGGTCAA...
# ...                                                                                               ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGGTTCATCC...    F80_Yolksac_Hep_FCAImmP8096696_TTTGGTTCATCCGTGG
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAAGATG...    F80_Yolksac_Hep_FCAImmP8096696_TTTGTCAAGATGCCAG
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCAGTCGA...    F80_Yolksac_Hep_FCAImmP8096696_TTTGTCAGTCGAACAG
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCATT...    F80_Yolksac_Hep_FCAImmP8096696_TTTGTCATCATTCACT
# F80_Yolksac_CD45NAF_FCAImmP8096696_TTTGTCATCGGA...    F80_Yolksac_Hep_FCAImmP8096696_TTTGTCATCGGATGGA
#
# [134765 rows x 14 columns]

# %%
np.max(adata.X)
# Out:
# 8.8560095

# %% [markdown]
# # By Broad

# %%
concat_indexer = pd.DataFrame()
concat_indexer
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
concat_indexer = pd.DataFrame()
paths = pd.DataFrame(pathlib.Path(pd_paths).glob("*early_late.csv"),columns = ['fpaths'])
for fpath in paths['fpaths']:
    enr_name = str(fpath).replace(pd_paths+'/','')
    enr_name = str(enr_name).replace('_sig_fc_early_late.csv','')
    print(enr_name)
    indexer = pd.read_csv(fpath,index_col=0)
    # make some fake neighbourhoods for computation
    if len(indexer[indexer['nhood_Sig_FC'].isin(['Early'])]) < 2:
        indexer.loc[indexer['logFC']<np.median(indexer['logFC']),'nhood_Sig_FC'] = 'Early'
    if len(indexer[indexer['nhood_Sig_FC'].isin(['Late'])]) < 2:
        indexer.loc[indexer['logFC']>np.median(indexer['logFC']),'nhood_Sig_FC'] = 'Late'
        
    #indexer = indexer[~indexer['nhood_Sig_FC'].isin(['False'])]    
    
    # if len still <0 then ignore this data

    #indexer = indexer[~indexer['nhood_Sig_FC'].isin(['False'])]
    indexer['cell_nhood_Sig_FC'] = enr_name + "_" + indexer['nhood_Sig_FC'].astype(str) 
    indexer = indexer.set_index('index_cell')
    concat_indexer = pd.concat([concat_indexer, indexer], axis=0)
concat_indexer.to_csv('all_milo_outs.csv')
# Out:
# NK
# HE
# Endoderm
# Monocyte
# MOP
# Monocyte_Macrophage
# Early_Erythroid
# Erythroid
# LMPP
# Pre_Macrophage
# CMP
# Mesothelium
# Prolif_Sinusoidal_EC
# Mono Mac pre DC2
# MK
# Sinusoidal_EC
# Macrophage
# MEMP
# Prolif_AEC
# Eo_Baso_Mast_precursor
# VWF_EC
# AEC
# Mac DC2
# Neutrophil_precursor
# Immature_EC
# Eo_Basophil
# HSPC_2
# Fibroblast
# Microglia
# HSPC_1
# Cycling DC2
# Lymphoid_progenitor
# Promonocyte
# Mast_cell
# Pre DC2
# Smooth_Muscle
# pDC precursor
# Mono Mac DC2

# %%
concat_indexer['broad_cell.labels'] = adata.obs['broad_cell.labels'][adata.obs.index.isin(concat_indexer.index)]
concat_indexer['broad_cell.labels']
# Out:
# index_cell
# F32_Yolksac_Total_FCAImmP7316900_TCGAGGCAGATAGCAT       Lymphoid
# F61_Yolksac_CD45P_FCAImmP7862089_ATCATGGTCGGCCGAT       Lymphoid
# F80_Yolksac_CD45P_FCAImmP8096693_GGGCATCTCAAGGCTT       Lymphoid
# Wang_et_al_CATGGCGTCGCCGTGA_2                        Endothelium
# F61_Yolksac_CD45P_FCAImmP7862089_ATTGGTGGTTAGGGTG    Endothelium
#                                                         ...
# F37_Yolksac_Total_FCAImmP7504911_TACACGAAGTGTGAAT             DC
# F37_Yolksac_Total_FCAImmP7504913_AAACCTGCACCCATTC             DC
# F37_Yolksac_Total_FCAImmP7504913_ACTGTCCGTCAATACC             DC
# F37_Yolksac_Total_FCAImmP7504913_CCGTACTCAGGCTCAC             DC
# F37_Yolksac_Total_FCAImmP7504913_CGTCCATGTCTGGAGA             DC
# Name: broad_cell.labels, Length: 5192, dtype: object

# %%
run_name = 'Early_late_DEGS'
Object = '/nfs/team205/ig7/work_backups/backup_210306/projects/YS/YS_data/A4_V7_YS_integrated_data_singlets_normalised_counts_for_MS_plotting_20211111_with_obsp.h5ad'
save_path = "/nfs/team205/ig7/work_backups/backup_210306/projects/YS/YS_310122_notebooks/fig1_background/scMILO/genescore_metabolic_early_late/outs/"
pd_paths = "/nfs/team205/ig7/work_backups/backup_210306/projects/YS/YS_310122_notebooks/fig1_background/scMILO/sig_FC_early_late_neighbourhoods"

# %%
import os
if not os.path.exists(save_path):
    os.makedirs(save_path)

# %%
concat_indexer['broad_cell.labels'].unique()
# Out:
# array(['Lymphoid', 'Endothelium', 'Endoderm', 'Monocyte', 'Progenitors',
#        'Erythroid', 'Macrophage', 'Mesothelium', 'DC', 'MK',
#        'Granulocyte_precursors', 'Fibroblast', 'Microglia', 'Mast_cell',
#        'Smooth_Muscle'], dtype=object)

# %%
    sig_testing = pd.DataFrame(data = [pvals,pvals],columns = gs_key)
    sig_testing['group'] = list(scores['group'].unique())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-8070a5b0242c> in <module>
#       1 sig_testing = pd.DataFrame(data = [pvals,pvals],columns = gs_key)
# ----> 2 sig_testing['group'] = list(scores['group'].unique())
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (4) does not match length of index (2)

# %%
indexer
# Out:
#                                                    kth_distance  SpatialFDR  \
# index_cell
# F35_Yolksac_Total_FCAImmP7462244_CACAAACAGATATGCA     22.693199    0.988394
# F61_Yolksac_CD45P_FCAImmP7862089_CATTATCAGCCACCTG     19.198458    0.881308
# F61_Yolksac_CD45P_FCAImmP7862089_CTAATGGAGAAACCTA     24.135900    0.853324
# F61_Yolksac_CD45P_FCAImmP7862089_GAACGGACAGACGCCT     22.456411    0.323653
# F61_Yolksac_CD45P_FCAImmP7862090_GAATGAACACCACCAG     22.667667    0.835051
# F61_Yolksac_CD45P_FCAImmP7862090_TAGCCGGTCCCTGACT     23.671703    0.323653
# F79_Yolksac_CD45P_FCAImmP8096688_TGCACCTAGAGTACCG     22.719685    0.938104
# F80_Yolksac_CD45P_FCAImmP8096689_CCCAATCGTTACCAGT     10.202361    0.931470
# F80_Yolksac_CD45P_FCAImmP8096693_AGAGCGATCCAGTATG     26.156530    0.918219
# Wang_et_al_TCTCTAATCGAGCCCA_2                         20.644741    0.606304
# F61_Yolksac_CD45P_FCAImmP7862088_ACACCGGTCCGCATCT     22.393753    0.323653
# F61_Yolksac_CD45P_FCAImmP7862088_CGCGGTATCATCTGTT     22.449448    0.323653
# F61_Yolksac_CD45P_FCAImmP7862090_CCTAGCTGTCGAGATG     22.234293    0.846922
# F61_Yolksac_CD45P_FCAImmP7862090_TTCTTAGTCGTACCGG     20.147089    0.909987
# F80_Yolksac_CD45P_FCAImmP8096689_GCTGCAGTCTATGTGG     19.217894    0.867517
# F80_Yolksac_CD45P_FCAImmP8096693_TTTCCTCAGTACACCT     20.741739    0.323653
#
#                                                       logFC    logCPM  \
# index_cell
# F35_Yolksac_Total_FCAImmP7462244_CACAAACAGATATGCA  0.720646  8.214169
# F61_Yolksac_CD45P_FCAImmP7862089_CATTATCAGCCACCTG  1.057066  8.529837
# F61_Yolksac_CD45P_FCAImmP7862089_CTAATGGAGAAACCTA  0.314167  7.995227
# F61_Yolksac_CD45P_FCAImmP7862089_GAACGGACAGACGCCT  3.342647  7.838017
# F61_Yolksac_CD45P_FCAImmP7862090_GAATGAACACCACCAG  0.265697  8.148394
# F61_Yolksac_CD45P_FCAImmP7862090_TAGCCGGTCCCTGACT  3.566402  8.069661
# F79_Yolksac_CD45P_FCAImmP8096688_TGCACCTAGAGTACCG  0.854303  8.192857
# F80_Yolksac_CD45P_FCAImmP8096689_CCCAATCGTTACCAGT  0.887756  8.511537
# F80_Yolksac_CD45P_FCAImmP8096693_AGAGCGATCCAGTATG  0.490691  7.663572
# Wang_et_al_TCTCTAATCGAGCCCA_2                     -0.165407  8.245663
# F61_Yolksac_CD45P_FCAImmP7862088_ACACCGGTCCGCATCT  3.595034  8.142262
# F61_Yolksac_CD45P_FCAImmP7862088_CGCGGTATCATCTGTT  3.543193  8.103880
# F61_Yolksac_CD45P_FCAImmP7862090_CCTAGCTGTCGAGATG  0.302521  7.928816
# F61_Yolksac_CD45P_FCAImmP7862090_TTCTTAGTCGTACCGG  0.935562  8.166343
# F80_Yolksac_CD45P_FCAImmP8096689_GCTGCAGTCTATGTGG  0.319269  8.204118
# F80_Yolksac_CD45P_FCAImmP8096693_TTTCCTCAGTACACCT  3.466889  8.275618
#
#                                                           F    PValue  \
# index_cell
# F35_Yolksac_Total_FCAImmP7462244_CACAAACAGATATGCA  0.000999  0.974782
# F61_Yolksac_CD45P_FCAImmP7862089_CATTATCAGCCACCTG  0.078855  0.778855
# F61_Yolksac_CD45P_FCAImmP7862089_CTAATGGAGAAACCTA  0.112988  0.736768
# F61_Yolksac_CD45P_FCAImmP7862089_GAACGGACAGACGCCT  2.259574  0.137832
# F61_Yolksac_CD45P_FCAImmP7862090_GAATGAACACCACCAG  0.140107  0.708176
# F61_Yolksac_CD45P_FCAImmP7862090_TAGCCGGTCCCTGACT  2.372005  0.123531
# F79_Yolksac_CD45P_FCAImmP8096688_TGCACCTAGAGTACCG  0.019969  0.887623
# F80_Yolksac_CD45P_FCAImmP8096689_CCCAATCGTTACCAGT  0.024713  0.875086
# F80_Yolksac_CD45P_FCAImmP8096693_AGAGCGATCCAGTATG  0.034944  0.851713
# Wang_et_al_TCTCTAATCGAGCCCA_2                      0.646957  0.421204
# F61_Yolksac_CD45P_FCAImmP7862088_ACACCGGTCCGCATCT  2.353888  0.124974
# F61_Yolksac_CD45P_FCAImmP7862088_CGCGGTATCATCTGTT  2.317882  0.127897
# F61_Yolksac_CD45P_FCAImmP7862090_CCTAGCTGTCGAGATG  0.123791  0.724960
# F61_Yolksac_CD45P_FCAImmP7862090_TTCTTAGTCGTACCGG  0.042656  0.836374
# F80_Yolksac_CD45P_FCAImmP8096689_GCTGCAGTCTATGTGG  0.095759  0.756980
# F80_Yolksac_CD45P_FCAImmP8096693_TTTCCTCAGTACACCT  2.115708  0.145797
#
#                                                         FDR   nhood_anno  \
# index_cell
# F35_Yolksac_Total_FCAImmP7462244_CACAAACAGATATGCA  0.989363     Monocyte
# F61_Yolksac_CD45P_FCAImmP7862089_CATTATCAGCCACCTG  0.891297     Monocyte
# F61_Yolksac_CD45P_FCAImmP7862089_CTAATGGAGAAACCTA  0.864961     Monocyte
# F61_Yolksac_CD45P_FCAImmP7862089_GAACGGACAGACGCCT  0.357108     Monocyte
# F61_Yolksac_CD45P_FCAImmP7862090_GAATGAACACCACCAG  0.847384     Monocyte
# F61_Yolksac_CD45P_FCAImmP7862090_TAGCCGGTCCCTGACT  0.357108     Monocyte
# F79_Yolksac_CD45P_FCAImmP8096688_TGCACCTAGAGTACCG  0.945127     Monocyte
# F80_Yolksac_CD45P_FCAImmP8096689_CCCAATCGTTACCAGT  0.938922     Monocyte
# F80_Yolksac_CD45P_FCAImmP8096693_AGAGCGATCCAGTATG  0.927066     Monocyte
# Wang_et_al_TCTCTAATCGAGCCCA_2                      0.620043  Promonocyte
# F61_Yolksac_CD45P_FCAImmP7862088_ACACCGGTCCGCATCT  0.357108  Promonocyte
# F61_Yolksac_CD45P_FCAImmP7862088_CGCGGTATCATCTGTT  0.357108  Promonocyte
# F61_Yolksac_CD45P_FCAImmP7862090_CCTAGCTGTCGAGATG  0.858183  Promonocyte
# F61_Yolksac_CD45P_FCAImmP7862090_TTCTTAGTCGTACCGG  0.918455  Promonocyte
# F80_Yolksac_CD45P_FCAImmP8096689_GCTGCAGTCTATGTGG  0.878659  Promonocyte
# F80_Yolksac_CD45P_FCAImmP8096693_TTTCCTCAGTACACCT  0.357108  Promonocyte
#
#                                                   anno_group nhood_Sig_FC  \
# index_cell
# F35_Yolksac_Total_FCAImmP7462244_CACAAACAGATATGCA   Monocyte        Early
# F61_Yolksac_CD45P_FCAImmP7862089_CATTATCAGCCACCTG   Monocyte        Early
# F61_Yolksac_CD45P_FCAImmP7862089_CTAATGGAGAAACCTA   Monocyte        Early
# F61_Yolksac_CD45P_FCAImmP7862089_GAACGGACAGACGCCT   Monocyte         Late
# F61_Yolksac_CD45P_FCAImmP7862090_GAATGAACACCACCAG   Monocyte        Early
# F61_Yolksac_CD45P_FCAImmP7862090_TAGCCGGTCCCTGACT   Monocyte         Late
# F79_Yolksac_CD45P_FCAImmP8096688_TGCACCTAGAGTACCG   Monocyte        Early
# F80_Yolksac_CD45P_FCAImmP8096689_CCCAATCGTTACCAGT   Monocyte        Early
# F80_Yolksac_CD45P_FCAImmP8096693_AGAGCGATCCAGTATG   Monocyte        Early
# Wang_et_al_TCTCTAATCGAGCCCA_2                       Monocyte        Early
# F61_Yolksac_CD45P_FCAImmP7862088_ACACCGGTCCGCATCT   Monocyte         Late
# F61_Yolksac_CD45P_FCAImmP7862088_CGCGGTATCATCTGTT   Monocyte         Late
# F61_Yolksac_CD45P_FCAImmP7862090_CCTAGCTGTCGAGATG   Monocyte        Early
# F61_Yolksac_CD45P_FCAImmP7862090_TTCTTAGTCGTACCGG   Monocyte        Early
# F80_Yolksac_CD45P_FCAImmP8096689_GCTGCAGTCTATGTGG   Monocyte        Early
# F80_Yolksac_CD45P_FCAImmP8096693_TTTCCTCAGTACACCT   Monocyte         Late
#
#                                                    cell_nhood_Sig_FC  \
# index_cell
# F35_Yolksac_Total_FCAImmP7462244_CACAAACAGATATGCA     Monocyte_Early
# F61_Yolksac_CD45P_FCAImmP7862089_CATTATCAGCCACCTG     Monocyte_Early
# F61_Yolksac_CD45P_FCAImmP7862089_CTAATGGAGAAACCTA     Monocyte_Early
# F61_Yolksac_CD45P_FCAImmP7862089_GAACGGACAGACGCCT      Monocyte_Late
# F61_Yolksac_CD45P_FCAImmP7862090_GAATGAACACCACCAG     Monocyte_Early
# F61_Yolksac_CD45P_FCAImmP7862090_TAGCCGGTCCCTGACT      Monocyte_Late
# F79_Yolksac_CD45P_FCAImmP8096688_TGCACCTAGAGTACCG     Monocyte_Early
# F80_Yolksac_CD45P_FCAImmP8096689_CCCAATCGTTACCAGT     Monocyte_Early
# F80_Yolksac_CD45P_FCAImmP8096693_AGAGCGATCCAGTATG     Monocyte_Early
# Wang_et_al_TCTCTAATCGAGCCCA_2                      Promonocyte_Early
# F61_Yolksac_CD45P_FCAImmP7862088_ACACCGGTCCGCATCT   Promonocyte_Late
# F61_Yolksac_CD45P_FCAImmP7862088_CGCGGTATCATCTGTT   Promonocyte_Late
# F61_Yolksac_CD45P_FCAImmP7862090_CCTAGCTGTCGAGATG  Promonocyte_Early
# F61_Yolksac_CD45P_FCAImmP7862090_TTCTTAGTCGTACCGG  Promonocyte_Early
# F80_Yolksac_CD45P_FCAImmP8096689_GCTGCAGTCTATGTGG  Promonocyte_Early
# F80_Yolksac_CD45P_FCAImmP8096693_TTTCCTCAGTACACCT   Promonocyte_Late
#
#                                                   broad_cell.labels
# index_cell
# F35_Yolksac_Total_FCAImmP7462244_CACAAACAGATATGCA          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862089_CATTATCAGCCACCTG          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862089_CTAATGGAGAAACCTA          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862089_GAACGGACAGACGCCT          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862090_GAATGAACACCACCAG          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862090_TAGCCGGTCCCTGACT          Monocyte
# F79_Yolksac_CD45P_FCAImmP8096688_TGCACCTAGAGTACCG          Monocyte
# F80_Yolksac_CD45P_FCAImmP8096689_CCCAATCGTTACCAGT          Monocyte
# F80_Yolksac_CD45P_FCAImmP8096693_AGAGCGATCCAGTATG          Monocyte
# Wang_et_al_TCTCTAATCGAGCCCA_2                              Monocyte
# F61_Yolksac_CD45P_FCAImmP7862088_ACACCGGTCCGCATCT          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862088_CGCGGTATCATCTGTT          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862090_CCTAGCTGTCGAGATG          Monocyte
# F61_Yolksac_CD45P_FCAImmP7862090_TTCTTAGTCGTACCGG          Monocyte
# F80_Yolksac_CD45P_FCAImmP8096689_GCTGCAGTCTATGTGG          Monocyte
# F80_Yolksac_CD45P_FCAImmP8096693_TTTCCTCAGTACACCT          Monocyte

# %%
from sklearn.preprocessing import MinMaxScaler
import scipy
scaler = MinMaxScaler(feature_range=(-1, 1))

gene_sets = {
'cell_cycle' : ['/nfs/team205/ig7/resources/GO-0022402_cell_cycle_genes.csv'],
'oxidative_metabolism' :['/nfs/team205/ig7/resources/GO-0045333_cell_respiration.csv'],
'glycolysis':['/nfs/team205/ig7/resources/HALLMARK_GLYCOLYSIS_M5937_.csv'],
            }

# collections
scores_totals = pd.DataFrame(columns = ([s + '_score' for s in list(gene_sets.keys())]+['group']))
scores_medians = pd.DataFrame(columns = ([s + '_score' for s in list(gene_sets.keys())])) 
scores_pvals = pd.DataFrame(columns = ([s + '_score' for s in list(gene_sets.keys())]+['group']))

rm_ls = list(adata.var[adata.var.index.str.startswith("MT-")].index) + list(adata.var[adata.var.index.str.startswith("RP11-")].index)
adata = adata[:,list(adata.var[~adata.var.index.isin(rm_ls)].index)]
for enr_name in concat_indexer['broad_cell.labels'].unique():
    indexer = concat_indexer[concat_indexer['broad_cell.labels'].isin([enr_name])]
    
    # make some fake neighbourhoods for computation
    if len(indexer[indexer['nhood_Sig_FC'].isin(['Early'])]) < 2:
        indexer.loc[indexer['logFC']<np.median(indexer['logFC']),'nhood_Sig_FC'] = 'Early'
    if len(indexer[indexer['nhood_Sig_FC'].isin(['Late'])]) < 2:
        indexer.loc[indexer['logFC']>np.median(indexer['logFC']),'nhood_Sig_FC'] = 'Late'

    # if len still <0 then ignore this data
    if min(indexer.groupby('nhood_Sig_FC').count().iloc[:,1]) >= 2 :
        indexer = indexer[~indexer['nhood_Sig_FC'].isin(['False'])]
        indexer['cell_nhood_Sig_FC'] = enr_name + "_" + indexer['nhood_Sig_FC'].astype(str) 
    temp = adata[adata.obs.index.isin(indexer.index)]
    temp.obs['cell_nhood_Sig_FC'] = indexer['cell_nhood_Sig_FC']
        
        
    gene_dictionary = {}
    for i in gene_sets.keys():
        gene_list_loc = ''.join(str(e) for e in gene_sets[i])
        gene_list_name = i
        gene_list = list(pd.read_csv(gene_list_loc,header=None)[0])
        gene_list = list(adata.var.index[adata.var.index.isin(gene_list)])
        print(len(gene_list))
        gene_dictionary[i] = gene_list
        sc.tl.score_genes(temp, gene_list, ctrl_size=100, gene_pool=None, n_bins=25, score_name=(gene_list_name + '_score'), random_state=0, copy=False, use_raw=None)

    #scores = np.log(temp.obs[[s + '_score' for s in list(gene_sets.keys())]])
# scale the outputs  by standard deviations
    scores = (pd.DataFrame(scaler.fit_transform((temp.obs[[s + '_score' for s in list(gene_sets.keys())]])), columns=(temp.obs[[s + '_score' for s in list(gene_sets.keys())]]).columns, index = (temp.obs[[s + '_score' for s in list(gene_sets.keys())]]).index))
    scores['group'] = temp.obs['cell_nhood_Sig_FC']
    
#Significance testing
    pvals = []
    statistics = []
    gs_key = []
    for gs in [s + '_score' for s in list(gene_sets.keys())]:
        temp_scores = scores[gs]
        stat_out = scipy.stats.ttest_ind(temp_scores[scores['group'].isin([scores['group'].unique()[0]])], temp_scores[scores['group'].isin([scores['group'].unique()[1]])], equal_var=False)
        pval = stat_out.pvalue
        statistic = stat_out.statistic
        pvals.append(pval)
        gs_key.append(gs)
    sig_testing = pd.DataFrame(data = [pvals,pvals],columns = gs_key)
    sig_testing['group'] = list(scores['group'].unique())
    
    scores_pvals = pd.concat([scores_pvals,sig_testing])
    scores_totals = pd.concat([scores_totals,scores])
    scores_medians = pd.concat([scores_medians,scores.groupby('group').median()])
# Out:
# /home/jovyan/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-35-09c7a51df239>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   indexer['nhood_Sig_FC'] = indexer['nhood_Sig_FC'].astype(str)
# Trying to set attribute `.obs` of view, copying.
# 1312
# computing score 'cell_cycle_score'
#     finished: added
#     'cell_cycle_score', score of gene set (adata.obs).
#     360 total control genes are used. (0:00:00)
# 172
# computing score 'oxidative_metabolism_score'
#     finished: added
#     'oxidative_metabolism_score', score of gene set (adata.obs).
#     390 total control genes are used. (0:00:00)
# 198
# computing score 'glycolysis_score'
#     finished: added
#     'glycolysis_score', score of gene set (adata.obs).
#     395 total control genes are used. (0:00:00)
# /home/jovyan/my-conda-envs/workhorse/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/jovyan/my-conda-envs/workhorse/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-35-09c7a51df239>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   indexer['nhood_Sig_FC'] = indexer['nhood_Sig_FC'].astype(str)
# Trying to set attribute `.obs` of view, copying.
# 1312
# computing score 'cell_cycle_score'
#     finished: added
#     'cell_cycle_score', score of gene set (adata.obs).
#     1398 total control genes are used. (0:00:00)
# 172
# computing score 'oxidative_metabolism_score'
#     finished: added
#     'oxidative_metabolism_score', score of gene set (adata.obs).
#     1484 total control genes are used. (0:00:00)
# 198
# computing score 'glycolysis_score'
#     finished: added
#     'glycolysis_score', score of gene set (adata.obs).
#     1485 total control genes are used. (0:00:00)
# <ipython-input-35-09c7a51df239>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   indexer['nhood_Sig_FC'] = indexer['nhood_Sig_FC'].astype(str)
# Trying to set attribute `.obs` of view, copying.
# 1312
# computing score 'cell_cycle_score'
#     finished: added
#     'cell_cycle_score', score of gene set (adata.obs).
#     1488 total control genes are used. (0:00:00)
# 172
# computing score 'oxidative_metabolism_score'
#     finished: added
#     'oxidative_metabolism_score', score of gene set (adata.obs).
#     1588 total control genes are used. (0:00:00)
# 198
# computing score 'glycolysis_score'
#     finished: added
#     'glycolysis_score', score of gene set (adata.obs).
#     1582 total control genes are used. (0:00:00)
# <ipython-input-35-09c7a51df239>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   indexer['nhood_Sig_FC'] = indexer['nhood_Sig_FC'].astype(str)
# Trying to set attribute `.obs` of view, copying.
# 1312
# computing score 'cell_cycle_score'
#     finished: added
#     'cell_cycle_score', score of gene set (adata.obs).
#     908 total control genes are used. (0:00:00)
# 172
# computing score 'oxidative_metabolism_score'
#     finished: added
#     'oxidative_metabolism_score', score of gene set (adata.obs).
#     990 total control genes are used. (0:00:00)
# 198
# computing score 'glycolysis_score'
#     finished: added
#     'glycolysis_score', score of gene set (adata.obs).
#     993 total control genes are used. (0:00:00)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-09c7a51df239> in <module>
#      63         gs_key.append(gs)
#      64     sig_testing = pd.DataFrame(data = [pvals,pvals],columns = gs_key)
# ---> 65     sig_testing['group'] = list(scores['group'].unique())
#      66
#      67     scores_pvals = pd.concat([scores_pvals,sig_testing])
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~/my-conda-envs/workhorse/lib/python3.8/site-packages/pandas/core/common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (4) does not match length of index (2)

# %%
scores['group']
# Out:
# F32_Yolksac_Total_FCAImmP7316900_TCGAGGCAGATAGCAT    NK_Early
# F61_Yolksac_CD45P_FCAImmP7862089_ATCATGGTCGGCCGAT    NK_False
# F80_Yolksac_CD45P_FCAImmP8096693_GGGCATCTCAAGGCTT     NK_Late
# Name: group, dtype: object

# %%
temp_scores[scores['group'].isin([scores['group'].unique()[0]])]
# Out:
# F32_Yolksac_Total_FCAImmP7316900_TCGAGGCAGATAGCAT   -1.0
# Name: glycolysis_score, dtype: float64

# %%
temp_scores[scores['group'].isin([scores['group'].unique()[1]])]
# Out:
# F61_Yolksac_CD45P_FCAImmP7862089_ATCATGGTCGGCCGAT    0.003584
# Name: glycolysis_score, dtype: float64

# %%
pvals
# Out:
# [nan, nan, nan]

# %% [markdown]
# # Write out outputs

# %%
geneset_concat = pd.DataFrame(columns = ['Genes','Geneset'])
gene_sets = {
'cell_cycle' : ['/nfs/team205/ig7/resources/GO-0022402_cell_cycle_genes.csv'],
'oxidative_metabolism' :['/nfs/team205/ig7/resources/GO-0045333_cell_respiration.csv'],
'glycolysis':['/nfs/team205/ig7/resources/HALLMARK_GLYCOLYSIS_M5937_.csv'],
            }
for i in gene_sets.keys():
    gene_list_loc = ''.join(str(e) for e in gene_sets[i])
    gene_list_name = i
    gene_list = list(pd.read_csv(gene_list_loc,header=None)[0])
    gene_list = list(adata.var.index[adata.var.index.isin(gene_list)])
    geneset_temp = pd.DataFrame(gene_list,columns = ['Genes'])
    geneset_temp['Geneset'] = i
    geneset_concat = pd.concat([geneset_concat,geneset_temp])
    
geneset_concat.to_csv('./genesets.csv')

# %%
pvals = scores_pvals[:]
pvals.columns = pvals.columns.str.replace('_score','_pvals')
pvals = pvals.set_index('group')
scores_medians_out = pd.concat([scores_medians,pvals],axis = 1,ignore_index=False)

scores_pvals.to_csv('./scores_pval.csv')
scores_totals.to_csv('./scores_totals.csv')
scores_medians_out.to_csv('./scores_medians.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3fac252de573> in <module>
# ----> 1 pvals = scores_pvals[:]
#       2 pvals.columns = pvals.columns.str.replace('_score','_pvals')
#       3 pvals = pvals.set_index('group')
#       4 scores_medians_out = pd.concat([scores_medians,pvals],axis = 1,ignore_index=False)
#       5
#
# NameError: name 'scores_pvals' is not defined

# %%
scores_pvals.loc[scores_pvals[col]!='*',col]
# Out:
# 0    1.896274e-01
# 1    1.896274e-01
# 0    4.751503e-01
# 1    4.751503e-01
# 0    1.862917e-02
# 1    1.862917e-02
# 0    1.862917e-02
# 1    1.862917e-02
# 0    6.492333e-01
# 1    6.492333e-01
# 0    6.977006e-36
# 1    6.977006e-36
# 0    1.106024e-03
# 1    1.106024e-03
# 0    1.756357e-02
# 1    1.756357e-02
# 0    2.584980e-01
# 1    2.584980e-01
# 0    2.918701e-01
# 1    2.918701e-01
# 0    2.918701e-01
# 1    2.918701e-01
# 0    9.893660e-02
# 1    9.893660e-02
# 0    4.554405e-01
# 1    4.554405e-01
# 0    4.771993e-01
# 1    4.771993e-01
# 0    1.896274e-01
# 1    1.896274e-01
# Name: cell_cycle_score, dtype: float64

# %%
for col in list(scores_pvals.columns[scores_pvals.columns.str.contains('_score')]):
# #     scores_pvals.loc[scores_pvals[col]<0.0001,col] = '***'
# #     scores_pvals.loc[scores_pvals[col]<0.001,col] = '**'
    scores_pvals = np.round(scores_pvals,4)
    scores_pvals.loc[scores_pvals[col]<0.05,col] = '*_' + scores_pvals.loc[scores_pvals[col]<0.05,col].astype(str)
#     scores_pvals.loc[scores_pvals[col].str.startswith('*'),col] = 'ns_'+ scores_pvals.loc[scores_pvals[col].str.startswith('*'),col].astype(str)
    print(col)
# Out:
# cell_cycle_score
# oxidative_metabolism_score
# glycolysis_score

# %%
scores_pvals
# Out:
#    cell_cycle_score  oxidative_metabolism_score  glycolysis_score  \
# 0               NaN                         NaN               NaN
# 1               NaN                         NaN               NaN
# 0          0.475150                5.527414e-07          0.003862
# 1          0.475150                5.527414e-07          0.003862
# 0          0.018629                3.908549e-01          0.066858
# 1          0.018629                3.908549e-01          0.066858
#
#                group
# 0           NK_Early
# 1            NK_Late
# 0  Endothelium_Early
# 1   Endothelium_Late
# 0     Endoderm_Early
# 1      Endoderm_Late

# %%
scores_medians
# Out:
#                      cell_cycle_score  oxidative_metabolism_score  \
# Smooth_Muscle_Early         -0.527934                   -0.219287
# Smooth_Muscle_Late          -0.147065                   -0.064022
# Endothelium_Early           -0.312452                    0.493266
# Endothelium_Late            -0.305213                    0.090619
# Endoderm_Early              -0.308531                    0.460828
# Endoderm_Late               -0.495186                    0.355370
# Endoderm_Early              -0.308531                    0.460828
# Endoderm_Late               -0.495186                    0.355370
# Progenitors_Early           -0.137451                    0.216819
# Progenitors_Late            -0.026321                    0.258443
# Erythroid_Early             -0.066515                    0.156615
# Erythroid_Late              -0.553847                   -0.325024
# Macrophage_Early            -0.132268                    0.306231
# Macrophage_Late             -0.064477                   -0.019564
# Mesothelium_Early           -0.290370                    0.128671
# Mesothelium_Late            -0.461413                   -0.489253
# DC_Early                     0.266339                    0.323413
# DC_Late                      0.199156                    0.250721
# MK_Early                    -0.415402                    0.379332
# MK_Late                     -0.409766                    0.251112
# MK_Early                    -0.415402                    0.379332
# MK_Late                     -0.409766                    0.251112
# Fibroblast_Early            -0.373084                    0.391682
# Fibroblast_Late             -0.438581                    0.287983
# Microglia_Early              0.498311                    0.938183
# Microglia_Late               0.390396                    0.057393
# Mast_cell_Early             -0.321953                    0.848802
# Mast_cell_Late              -0.682889                   -0.995524
# Smooth_Muscle_Early         -0.527934                   -0.219287
# Smooth_Muscle_Late          -0.147065                   -0.064022
#
#                      glycolysis_score
# Smooth_Muscle_Early         -0.016584
# Smooth_Muscle_Late          -0.020441
# Endothelium_Early           -0.105220
# Endothelium_Late            -0.273157
# Endoderm_Early               0.242527
# Endoderm_Late                0.059466
# Endoderm_Early               0.242527
# Endoderm_Late                0.059466
# Progenitors_Early            0.280427
# Progenitors_Late             0.015290
# Erythroid_Early             -0.244630
# Erythroid_Late              -0.541929
# Macrophage_Early            -0.008721
# Macrophage_Late             -0.213882
# Mesothelium_Early           -0.313574
# Mesothelium_Late            -0.039816
# DC_Early                     0.154485
# DC_Late                     -0.025169
# MK_Early                     0.685732
# MK_Late                      0.303894
# MK_Early                     0.685732
# MK_Late                      0.303894
# Fibroblast_Early             0.031243
# Fibroblast_Late             -0.226686
# Microglia_Early             -0.711578
# Microglia_Late              -0.059522
# Mast_cell_Early             -0.260178
# Mast_cell_Late              -0.693813
# Smooth_Muscle_Early         -0.016584
# Smooth_Muscle_Late          -0.020441

# %%
annot
# Out:
# array([['ns', 'ns', 'ns'],
#        ['ns', 'ns', 'ns'],
#        ['ns', 'sig', 'sig'],
#        ['ns', 'sig', 'sig'],
#        ['sig', 'ns', 'ns'],
#        ['sig', 'ns', 'ns'],
#        ['sig', 'ns', 'ns'],
#        ['sig', 'ns', 'ns'],
#        ['ns', 'ns', 'sig'],
#        ['ns', 'ns', 'sig'],
#        ['sig', 'sig', 'sig'],
#        ['sig', 'sig', 'sig'],
#        ['sig', 'sig', 'sig'],
#        ['sig', 'sig', 'sig'],
#        ['sig', 'ns', 'ns'],
#        ['sig', 'ns', 'ns'],
#        ['ns', 'ns', 'ns'],
#        ['ns', 'ns', 'ns'],
#        ['ns', 'ns', 'sig'],
#        ['ns', 'ns', 'sig'],
#        ['ns', 'ns', 'sig'],
#        ['ns', 'ns', 'sig'],
#        ['ns', 'sig', 'sig'],
#        ['ns', 'sig', 'sig'],
#        ['ns', 'sig', 'ns'],
#        ['ns', 'sig', 'ns'],
#        ['ns', 'ns', 'ns'],
#        ['ns', 'ns', 'ns'],
#        ['ns', 'ns', 'ns'],
#        ['ns', 'ns', 'ns']], dtype=object)

# %%
scores_medians = pd.read_csv('./scores_medians.csv',index_col =0)
scores_pvals = pd.read_csv('./scores_pval.csv',index_col =0)
scores_totals = pd.read_csv('./scores_totals.csv',index_col = 0)

# %%
scores_medians = scores_medians[['cell_cycle_score', 'oxidative_metabolism_score', 'glycolysis_score']]

# %%
plt.figure(figsize=(8,20))
sns.set(font_scale=0.5)
pal = (sns.diverging_palette(240, 10, n=9))

annot = np.array(scores_pvals[list(scores_pvals.columns[scores_pvals.columns.str.contains('_score')])])
# g = sns.heatmap(scores_medians,  annot=True,vmin=-1, vmax=1, linewidths=1, center=0, cmap = pal, square=True, cbar_kws={"shrink": 0.5})
g = sns.heatmap(scores_medians,  annot=annot,vmin=-1, vmax=1, linewidths=1, center=0, cmap = pal, square=True, cbar_kws={"shrink": 0.5},fmt='')

plt.title('Geneset module Z-scores and pvalues', fontdict=None, loc='center')
plt.xticks(rotation=90,fontsize=14)
plt.yticks(rotation=0,fontsize=14)
plt.ylabel("Neighbourhood")
plt.xlabel("Module Z-score")
plt.savefig('./Milo_geneset_module_scores.pdf',dpi=300)

# %% [markdown]
# # V2 plot

# %%
gene_sets = {
'cell_cycle' : ['/nfs/team205/ig7/resources/GO-0022402_cell_cycle_genes.csv'],
'oxidative_metabolism' :['/nfs/team205/ig7/resources/GO-0045333_cell_respiration.csv'],
'glycolysis':['/nfs/team205/ig7/resources/HALLMARK_GLYCOLYSIS_M5937_.csv'],
            }

# %%
scores_totals
# Out:
#                                                     cell_cycle_score  \
# Wang_et_al_TTTACTGCATTCCTGC_2                               0.171160
# F37_Yolksac_Total_FCAImmP7504911_TCAGGTATCCAGAGGA          -0.492473
# F37_Yolksac_Total_FCAImmP7504912_AGCTCCTGTAGAGGAA          -0.202957
# F37_Yolksac_Total_FCAImmP7504912_GTCGTAAGTTCTCATT          -0.324382
# F61_Yolksac_CD45P_FCAImmP7862088_TACGGTAAGGAGTTTA          -0.430583
# ...                                                              ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_CCACGGAGTCTA...         -0.717430
# F80_Yolksac_CD45NAF_FCAImmP8096696_CTCGTACAGTTC...         -0.205336
# F80_Yolksac_CD45NAF_FCAImmP8096696_GCTGGGTTCAGT...         -0.285823
# F80_Yolksac_CD45NAF_FCAImmP8096696_GGGACCTCATGT...         -0.560001
# F80_Yolksac_CD45NAF_FCAImmP8096696_TGAGCATGTACC...         -0.199795
#
#                                                     oxidative_metabolism_score  \
# Wang_et_al_TTTACTGCATTCCTGC_2                                        -0.219287
# F37_Yolksac_Total_FCAImmP7504911_TCAGGTATCCAGAGGA                     0.779960
# F37_Yolksac_Total_FCAImmP7504912_AGCTCCTGTAGAGGAA                     0.452694
# F37_Yolksac_Total_FCAImmP7504912_GTCGTAAGTTCTCATT                     1.000000
# F61_Yolksac_CD45P_FCAImmP7862088_TACGGTAAGGAGTTTA                    -0.160667
# ...                                                                        ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_CCACGGAGTCTA...                    0.161061
# F80_Yolksac_CD45NAF_FCAImmP8096696_CTCGTACAGTTC...                    0.494880
# F80_Yolksac_CD45NAF_FCAImmP8096696_GCTGGGTTCAGT...                    0.801155
# F80_Yolksac_CD45NAF_FCAImmP8096696_GGGACCTCATGT...                    0.509198
# F80_Yolksac_CD45NAF_FCAImmP8096696_TGAGCATGTACC...                    0.717339
#
#                                                     glycolysis_score  \
# Wang_et_al_TTTACTGCATTCCTGC_2                               0.996298
# F37_Yolksac_Total_FCAImmP7504911_TCAGGTATCCAGAGGA           0.184944
# F37_Yolksac_Total_FCAImmP7504912_AGCTCCTGTAGAGGAA           0.127488
# F37_Yolksac_Total_FCAImmP7504912_GTCGTAAGTTCTCATT          -0.069774
# F61_Yolksac_CD45P_FCAImmP7862088_TACGGTAAGGAGTTTA          -0.024916
# ...                                                              ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_CCACGGAGTCTA...         -0.016584
# F80_Yolksac_CD45NAF_FCAImmP8096696_CTCGTACAGTTC...          0.617388
# F80_Yolksac_CD45NAF_FCAImmP8096696_GCTGGGTTCAGT...         -0.060453
# F80_Yolksac_CD45NAF_FCAImmP8096696_GGGACCTCATGT...         -0.230360
# F80_Yolksac_CD45NAF_FCAImmP8096696_TGAGCATGTACC...         -0.012155
#
#                                                                   group
# Wang_et_al_TTTACTGCATTCCTGC_2                       Smooth_Muscle_Early
# F37_Yolksac_Total_FCAImmP7504911_TCAGGTATCCAGAGGA    Smooth_Muscle_Late
# F37_Yolksac_Total_FCAImmP7504912_AGCTCCTGTAGAGGAA    Smooth_Muscle_Late
# F37_Yolksac_Total_FCAImmP7504912_GTCGTAAGTTCTCATT    Smooth_Muscle_Late
# F61_Yolksac_CD45P_FCAImmP7862088_TACGGTAAGGAGTTTA    Smooth_Muscle_Late
# ...                                                                 ...
# F80_Yolksac_CD45NAF_FCAImmP8096696_CCACGGAGTCTA...  Smooth_Muscle_Early
# F80_Yolksac_CD45NAF_FCAImmP8096696_CTCGTACAGTTC...   Smooth_Muscle_Late
# F80_Yolksac_CD45NAF_FCAImmP8096696_GCTGGGTTCAGT...   Smooth_Muscle_Late
# F80_Yolksac_CD45NAF_FCAImmP8096696_GGGACCTCATGT...   Smooth_Muscle_Late
# F80_Yolksac_CD45NAF_FCAImmP8096696_TGAGCATGTACC...   Smooth_Muscle_Late
#
# [3462 rows x 4 columns]

# %%
scores_medians = scores_totals.groupby('group').median()

plt.figure(figsize=(8,20))
sns.set(font_scale=0.5)
pal = (sns.diverging_palette(240, 10, n=20))

annot = np.array(scores_pvals[list(scores_pvals.columns[scores_pvals.columns.str.contains('_score')])])
# g = sns.heatmap(scores_medians,  annot=True,vmin=-1, vmax=1, linewidths=1, center=0, cmap = pal, square=True, cbar_kws={"shrink": 0.5})
g = sns.heatmap(scores_medians,  annot=False,vmin=-1, vmax=1, linewidths=1, center=0, cmap = pal, square=True, cbar_kws={"shrink": 0.5},fmt='')

plt.title('Geneset module Z-scores and pvalues', fontdict=None, loc='center')
plt.xticks(rotation=90,fontsize=14)
plt.yticks(rotation=0,fontsize=14)
plt.ylabel("Neighbourhood")
plt.xlabel("Module Z-score")
plt.savefig('./Milo_geneset_module_scores_no_annot.pdf',dpi=300)

# %%
scores_medians
# Out:
#                      cell_cycle_score  oxidative_metabolism_score  \
# Smooth_Muscle_Early         -0.527934                   -0.219287
# Smooth_Muscle_Late          -0.147065                   -0.064022
# Endothelium_Early           -0.312452                    0.493266
# Endothelium_Late            -0.305213                    0.090619
# Endoderm_Early              -0.308531                    0.460828
# Endoderm_Late               -0.495186                    0.355370
# Endoderm_Early              -0.308531                    0.460828
# Endoderm_Late               -0.495186                    0.355370
# Progenitors_Early           -0.137451                    0.216819
# Progenitors_Late            -0.026321                    0.258443
# Erythroid_Early             -0.066515                    0.156615
# Erythroid_Late              -0.553847                   -0.325024
# Macrophage_Early            -0.132268                    0.306231
# Macrophage_Late             -0.064477                   -0.019564
# Mesothelium_Early           -0.290370                    0.128671
# Mesothelium_Late            -0.461413                   -0.489253
# DC_Early                     0.266339                    0.323413
# DC_Late                      0.199156                    0.250721
# MK_Early                    -0.415402                    0.379332
# MK_Late                     -0.409766                    0.251112
# MK_Early                    -0.415402                    0.379332
# MK_Late                     -0.409766                    0.251112
# Fibroblast_Early            -0.373084                    0.391682
# Fibroblast_Late             -0.438581                    0.287983
# Microglia_Early              0.498311                    0.938183
# Microglia_Late               0.390396                    0.057393
# Mast_cell_Early             -0.321953                    0.848802
# Mast_cell_Late              -0.682889                   -0.995524
# Smooth_Muscle_Early         -0.527934                   -0.219287
# Smooth_Muscle_Late          -0.147065                   -0.064022
#
#                      glycolysis_score
# Smooth_Muscle_Early         -0.016584
# Smooth_Muscle_Late          -0.020441
# Endothelium_Early           -0.105220
# Endothelium_Late            -0.273157
# Endoderm_Early               0.242527
# Endoderm_Late                0.059466
# Endoderm_Early               0.242527
# Endoderm_Late                0.059466
# Progenitors_Early            0.280427
# Progenitors_Late             0.015290
# Erythroid_Early             -0.244630
# Erythroid_Late              -0.541929
# Macrophage_Early            -0.008721
# Macrophage_Late             -0.213882
# Mesothelium_Early           -0.313574
# Mesothelium_Late            -0.039816
# DC_Early                     0.154485
# DC_Late                     -0.025169
# MK_Early                     0.685732
# MK_Late                      0.303894
# MK_Early                     0.685732
# MK_Late                      0.303894
# Fibroblast_Early             0.031243
# Fibroblast_Late             -0.226686
# Microglia_Early             -0.711578
# Microglia_Late              -0.059522
# Mast_cell_Early             -0.260178
# Mast_cell_Late              -0.693813
# Smooth_Muscle_Early         -0.016584
# Smooth_Muscle_Late          -0.020441
